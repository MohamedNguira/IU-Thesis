# %%
import gym
import torch
import collections
import matplotlib
import matplotlib.pyplot as plt

import sys
sys.path.append("../environments") 

from tsitsiklis import *

# %% [markdown]
# The MDP should obtain a uniform distribution of state visits under its behavioral policy. Or in other words, when following the behavioral policy for some time, all 7 states should receive approximately equal number of visits.

# %%
def behavior(env, eps):
    """ Calculates action taken by Baird's counterexample behavioral policy. """
    if float(torch.rand(1)) > eps:
        return 1 # Solid action
    else:
        return 0 # Dashed action

# %%
env = gym.make('TsitsiklisVanRoyCounterexample-v0')
env.reset()

states = []
for i in range(10_000):
    action = behavior(env, 0.1)
    state, reward, done, info = env.step(action)
    states += [state]
# Out:
# c:\Users\m4mou\AppData\Local\Programs\Python\Python312\Lib\site-packages\gym\utils\passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# c:\Users\m4mou\AppData\Local\Programs\Python\Python312\Lib\site-packages\gym\utils\passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# c:\Users\m4mou\AppData\Local\Programs\Python\Python312\Lib\site-packages\gym\utils\passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'int'>`
#   logger.warn(
# c:\Users\m4mou\AppData\Local\Programs\Python\Python312\Lib\site-packages\gym\utils\passive_env_checker.py:219: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# c:\Users\m4mou\AppData\Local\Programs\Python\Python312\Lib\site-packages\gym\utils\passive_env_checker.py:225: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):

# %%
matplotlib.rcParams['figure.figsize'] = [10, 5]

bins = range(1, env.observation_space.n + 1)
plt.hist(states, bins=bins, rwidth=0.75, align='left')

plt.xlabel("State")
plt.ylabel("Number of Visits")

plt.show()

# %% [markdown]
# ### Divergence of Q-learning with Function Approximation on Baird's Counterexample MDP
#
# Demonstration of instability on Baird's counterexample MDP. The chart shows evolution of
# the components of the parameter vector $\boldsymbol{w}$. The step size was $\alpha = 0.05$.
# For each action the Q-value weights vector $\boldsymbol{w}$ was initialized in exactly the
# same way as in Figure 11.2. Experimentation showed that initialization doesn't have a
# qualitative effect on the divergence.

# %%
def approximate_q_learning(env, n_steps, gamma = 0.99, alpha = 0.05):
    """ Optimizes weights vector using Q-learning with function approximation.

    The function uses the following version of the Q-learning 
    algorithm with linear function approximation:
        0. Initialize weights to a small random value.
        1. Sample state, action, reward and next_state
        2. Calculate Q target estimate using reward, next_state
           and maximal next action.
        3. Calculate Q value estimate and it's gradient for the
           state and taken action.
        4. Update weights so the Q value for the state and taken
           action to be closer to target.
        5. Goto 1, unless the terminal condition is met.
    """
    assert type(env.observation_space) == gym.spaces.Discrete
    assert type(env.action_space) == gym.spaces.Discrete
    assert env.observation_space.n == 3
    assert env.action_space.n == 2

    features = torch.tensor(
        [
            [1],  # Upper state 1
            [2],  # Upper state 2
            [0],  # Lower state
        ],
        dtype=torch.float,
        requires_grad=False
    )
    weights = torch.randn((1), requires_grad=True)


    def q(state, action):
        """ Calculates approxiate Q value for the specified state and action. """
        nonlocal weights, features
        return features[state] @ weights

    def q_update(state, action, reward, next_state):
        """ Updates the weights vector using the Q-learning rule with AD gradient. """
        nonlocal weights

        q_value = q(state, action)
        q_target = reward + gamma * torch.max(q(next_state, 0), q(next_state, 1))
        delta = q_target - q_value

        q_value.backward()
        with torch.no_grad():
            weights += alpha * delta * weights.grad
            weights.grad.zero_()

    step = 1
    done = False
    history0, history1 = [], []
    state = env.reset()

    while step < n_steps:
        action = behavior(env,1)

        next_state, reward, done, info = env.step(action)
        q_update(state, action, reward, next_state)
        
        state = next_state
        step += 1
        
        history0 += [weights[0].detach().numpy().copy()]
        if done:
            env.reset()

    return history0

# %%
env = gym.make('TsitsiklisVanRoyCounterexample-v0')
history = approximate_q_learning(env, n_steps=10000, gamma=0.99, alpha=0.5)
history
# Out:
# [array(-0.37659666, dtype=float32),
#  array(-0.36906472, dtype=float32),
#  array(-0.36168346, dtype=float32),
#  array(-0.35444978, dtype=float32),
#  array(-0.34736082, dtype=float32),
#  array(-0.3404136, dtype=float32),
#  array(-0.33360532, dtype=float32),
#  array(-0.32693323, dtype=float32),
#  array(-0.3203946, dtype=float32),
#  array(-0.31398675, dtype=float32),
#  array(-0.30770704, dtype=float32),
#  array(-0.30155292, dtype=float32),
#  array(-0.2955219, dtype=float32),
#  array(-0.28961143, dtype=float32),
#  array(-0.28381923, dtype=float32),
#  array(-0.27814284, dtype=float32),
#  array(-0.27258, dtype=float32),
#  array(-0.26712838, dtype=float32),
#  array(-0.26178584, dtype=float32),
#  array(-0.2565501, dtype=float32),
#  array(-0.2514191, dtype=float32),
#  array(-0.24639073, dtype=float32),
#  array(-0.24146292, dtype=float32),
#  array(-0.23663366, dtype=float32),
#  array(-0.23190099, dtype=float32),
#  array(-0.22726297, dtype=float32),
#  array(-0.22271773, dtype=float32),
#  array(-0.21826339, dtype=float32),
#  array(-0.21389812, dtype=float32),
#  array(-0.20962018, dtype=float32),
#  array(-0.20542777, dtype=float32),
#  array(-0.20131922, dtype=float32),
#  array(-0.19729283, dtype=float32),
#  array(-0.19334698, dtype=float32),
#  array(-0.18948004, dtype=float32),
#  array(-0.18569043, dtype=float32),
#  array(-0.18197662, dtype=float32),
#  array(-0.1783371, dtype=float32),
#  array(-0.17477036, dtype=float32),
#  array(-0.17127496, dtype=float32),
#  array(-0.16784945, dtype=float32),
#  array(-0.16449246, dtype=float32),
#  array(-0.16120261, dtype=float32),
#  array(-0.15797856, dtype=float32),
#  array(-0.15481898, dtype=float32),
#  array(-0.15172261, dtype=float32),
#  array(-0.14868817, dtype=float32),
#  array(-0.1457144, dtype=float32),
#  array(-0.14280012, dtype=float32),
#  array(-0.13994414, dtype=float32),
#  array(-0.13714525, dtype=float32),
#  array(-0.13440233, dtype=float32),
#  array(-0.13171428, dtype=float32),
#  array(-0.12908, dtype=float32),
#  array(-0.1264984, dtype=float32),
#  array(-0.12396842, dtype=float32),
#  array(-0.12148906, dtype=float32),
#  array(-0.11905928, dtype=float32),
#  array(-0.11667809, dtype=float32),
#  array(-0.11434452, dtype=float32),
#  array(-0.11205764, dtype=float32),
#  array(-0.10981649, dtype=float32),
#  array(-0.10762016, dtype=float32),
#  array(-0.10546777, dtype=float32),
#  array(-0.10335842, dtype=float32),
#  array(-0.10129125, dtype=float32),
#  array(-0.09926543, dtype=float32),
#  array(-0.09728011, dtype=float32),
#  array(-0.09533451, dtype=float32),
#  array(-0.09342782, dtype=float32),
#  array(-0.09155926, dtype=float32),
#  array(-0.08972807, dtype=float32),
#  array(-0.08793351, dtype=float32),
#  array(-0.08617485, dtype=float32),
#  array(-0.08445135, dtype=float32),
#  array(-0.08276232, dtype=float32),
#  array(-0.08110707, dtype=float32),
#  array(-0.07948492, dtype=float32),
#  array(-0.07789522, dtype=float32),
#  array(-0.07633732, dtype=float32),
#  array(-0.07481058, dtype=float32),
#  array(-0.07331437, dtype=float32),
#  array(-0.07184808, dtype=float32),
#  array(-0.07041112, dtype=float32),
#  array(-0.0690029, dtype=float32),
#  array(-0.06762284, dtype=float32),
#  array(-0.06627038, dtype=float32),
#  array(-0.06494497, dtype=float32),
#  array(-0.06364606, dtype=float32),
#  array(-0.06237315, dtype=float32),
#  array(-0.06112569, dtype=float32),
#  array(-0.05990317, dtype=float32),
#  array(-0.05870511, dtype=float32),
#  array(-0.05753101, dtype=float32),
#  array(-0.0563804, dtype=float32),
#  array(-0.05525279, dtype=float32),
#  array(-0.05414774, dtype=float32),
#  array(-0.05306478, dtype=float32),
#  array(-0.05200348, dtype=float32),
#  array(-0.05096341, dtype=float32),
#  array(-0.04994414, dtype=float32),
#  array(-0.04894526, dtype=float32),
#  array(-0.04796635, dtype=float32),
#  array(-0.04700702, dtype=float32),
#  array(-0.04606689, dtype=float32),
#  array(-0.04514555, dtype=float32),
#  array(-0.04424264, dtype=float32),
#  array(-0.04335778, dtype=float32),
#  array(-0.04249062, dtype=float32),
#  array(-0.04164081, dtype=float32),
#  array(-0.04080799, dtype=float32),
#  array(-0.03999183, dtype=float32),
#  array(-0.039192, dtype=float32),
#  array(-0.03840816, dtype=float32),
#  array(-0.03764, dtype=float32),
#  array(-0.0368872, dtype=float32),
#  array(-0.03614946, dtype=float32),
#  array(-0.03542647, dtype=float32),
#  array(-0.03471794, dtype=float32),
#  array(-0.03402358, dtype=float32),
#  array(-0.03334311, dtype=float32),
#  array(-0.03267625, dtype=float32),
#  array(-0.03202272, dtype=float32),
#  array(-0.03138227, dtype=float32),
#  array(-0.03075463, dtype=float32),
#  array(-0.03013954, dtype=float32),
#  array(-0.02953675, dtype=float32),
#  array(-0.02894601, dtype=float32),
#  array(-0.02836709, dtype=float32),
#  array(-0.02779975, dtype=float32),
#  array(-0.02724375, dtype=float32),
#  array(-0.02669888, dtype=float32),
#  array(-0.0261649, dtype=float32),
#  array(-0.0256416, dtype=float32),
#  array(-0.02512877, dtype=float32),
#  array(-0.0246262, dtype=float32),
#  array(-0.02413367, dtype=float32),
#  array(-0.023651, dtype=float32),
#  array(-0.02317798, dtype=float32),
#  array(-0.02271442, dtype=float32),
#  array(-0.02226013, dtype=float32),
#  array(-0.02181493, dtype=float32),
#  array(-0.02137863, dtype=float32),
#  array(-0.02095105, dtype=float32),
#  array(-0.02053203, dtype=float32),
#  array(-0.0201214, dtype=float32),
#  array(-0.01971897, dtype=float32),
#  array(-0.01932459, dtype=float32),
#  array(-0.0189381, dtype=float32),
#  array(-0.01855934, dtype=float32),
#  array(-0.01818815, dtype=float32),
#  array(-0.01782439, dtype=float32),
#  array(-0.0174679, dtype=float32),
#  array(-0.01711854, dtype=float32),
#  array(-0.01677617, dtype=float32),
#  array(-0.01644065, dtype=float32),
#  array(-0.01611184, dtype=float32),
#  array(-0.0157896, dtype=float32),
#  array(-0.01547381, dtype=float32),
#  array(-0.01516433, dtype=float32),
#  array(-0.01486104, dtype=float32),
#  array(-0.01456382, dtype=float32),
#  array(-0.01427254, dtype=float32),
#  array(-0.01398709, dtype=float32),
#  array(-0.01370735, dtype=float32),
#  array(-0.01343321, dtype=float32),
#  array(-0.01316454, dtype=float32),
#  array(-0.01290125, dtype=float32),
#  array(-0.01264323, dtype=float32),
#  array(-0.01239036, dtype=float32),
#  array(-0.01214256, dtype=float32),
#  array(-0.01189971, dtype=float32),
#  array(-0.01166171, dtype=float32),
#  array(-0.01142848, dtype=float32),
#  array(-0.01119991, dtype=float32),
#  array(-0.01097591, dtype=float32),
#  array(-0.01075639, dtype=float32),
#  array(-0.01054126, dtype=float32),
#  array(-0.01033044, dtype=float32),
#  array(-0.01012383, dtype=float32),
#  array(-0.00992135, dtype=float32),
#  array(-0.00972293, dtype=float32),
#  array(-0.00952847, dtype=float32),
#  array(-0.0093379, dtype=float32),
#  array(-0.00915114, dtype=float32),
#  array(-0.00896812, dtype=float32),
#  array(-0.00878876, dtype=float32),
#  array(-0.00861298, dtype=float32),
#  array(-0.00844072, dtype=float32),
#  array(-0.00827191, dtype=float32),
#  array(-0.00810647, dtype=float32),
#  array(-0.00794434, dtype=float32),
#  array(-0.00778545, dtype=float32),
#  array(-0.00762975, dtype=float32),
#  array(-0.00747715, dtype=float32),
#  array(-0.00732761, dtype=float32),
#  array(-0.00718106, dtype=float32),
#  array(-0.00703744, dtype=float32),
#  array(-0.00689669, dtype=float32),
#  array(-0.00675875, dtype=float32),
#  array(-0.00662358, dtype=float32),
#  array(-0.00649111, dtype=float32),
#  array(-0.00636129, dtype=float32),
#  array(-0.00623406, dtype=float32),
#  array(-0.00610938, dtype=float32),
#  array(-0.00598719, dtype=float32),
#  array(-0.00586745, dtype=float32),
#  array(-0.0057501, dtype=float32),
#  array(-0.0056351, dtype=float32),
#  array(-0.0055224, dtype=float32),
#  array(-0.00541195, dtype=float32),
#  array(-0.00530371, dtype=float32),
#  array(-0.00519763, dtype=float32),
#  array(-0.00509368, dtype=float32),
#  array(-0.00499181, dtype=float32),
#  array(-0.00489197, dtype=float32),
#  array(-0.00479413, dtype=float32),
#  array(-0.00469825, dtype=float32),
#  array(-0.00460429, dtype=float32),
#  array(-0.0045122, dtype=float32),
#  array(-0.00442196, dtype=float32),
#  array(-0.00433352, dtype=float32),
#  array(-0.00424685, dtype=float32),
#  array(-0.00416191, dtype=float32),
#  array(-0.00407867, dtype=float32),
#  array(-0.0039971, dtype=float32),
#  array(-0.00391716, dtype=float32),
#  array(-0.00383881, dtype=float32),
#  array(-0.00376204, dtype=float32),
#  array(-0.0036868, dtype=float32),
#  array(-0.00361306, dtype=float32),
#  array(-0.0035408, dtype=float32),
#  array(-0.00346998, dtype=float32),
#  array(-0.00340058, dtype=float32),
#  array(-0.00333257, dtype=float32),
#  array(-0.00326592, dtype=float32),
#  array(-0.0032006, dtype=float32),
#  array(-0.00313659, dtype=float32),
#  array(-0.00307386, dtype=float32),
#  array(-0.00301238, dtype=float32),
#  array(-0.00295213, dtype=float32),
#  array(-0.00289309, dtype=float32),
#  array(-0.00283523, dtype=float32),
#  array(-0.00277853, dtype=float32),
#  array(-0.00272296, dtype=float32),
#  array(-0.0026685, dtype=float32),
#  array(-0.00261513, dtype=float32),
#  array(-0.00256282, dtype=float32),
#  array(-0.00251157, dtype=float32),
#  array(-0.00246134, dtype=float32),
#  array(-0.00241211, dtype=float32),
#  array(-0.00236387, dtype=float32),
#  array(-0.00231659, dtype=float32),
#  array(-0.00227026, dtype=float32),
#  array(-0.00222485, dtype=float32),
#  array(-0.00218036, dtype=float32),
#  array(-0.00213675, dtype=float32),
#  array(-0.00209401, dtype=float32),
#  array(-0.00205213, dtype=float32),
#  array(-0.00201109, dtype=float32),
#  array(-0.00197087, dtype=float32),
#  array(-0.00193145, dtype=float32),
#  array(-0.00189282, dtype=float32),
#  array(-0.00185497, dtype=float32),
#  array(-0.00181787, dtype=float32),
#  array(-0.00178151, dtype=float32),
#  array(-0.00174588, dtype=float32),
#  array(-0.00171096, dtype=float32),
#  array(-0.00167674, dtype=float32),
#  array(-0.00164321, dtype=float32),
#  array(-0.00161034, dtype=float32),
#  array(-0.00157814, dtype=float32),
#  array(-0.00154658, dtype=float32),
#  array(-0.00151564, dtype=float32),
#  array(-0.00148533, dtype=float32),
#  array(-0.00145562, dtype=float32),
#  array(-0.00142651, dtype=float32),
#  array(-0.00139798, dtype=float32),
#  array(-0.00137002, dtype=float32),
#  array(-0.00134262, dtype=float32),
#  array(-0.00131577, dtype=float32),
#  array(-0.00128945, dtype=float32),
#  array(-0.00126366, dtype=float32),
#  array(-0.00123839, dtype=float32),
#  array(-0.00121362, dtype=float32),
#  array(-0.00118935, dtype=float32),
#  array(-0.00116556, dtype=float32),
#  array(-0.00114225, dtype=float32),
#  array(-0.00111941, dtype=float32),
#  array(-0.00109702, dtype=float32),
#  array(-0.00107508, dtype=float32),
#  array(-0.00105358, dtype=float32),
#  array(-0.00103251, dtype=float32),
#  array(-0.00101186, dtype=float32),
#  array(-0.00099162, dtype=float32),
#  array(-0.00097179, dtype=float32),
#  array(-0.00095235, dtype=float32),
#  array(-0.0009333, dtype=float32),
#  array(-0.00091464, dtype=float32),
#  array(-0.00089635, dtype=float32),
#  array(-0.00087842, dtype=float32),
#  array(-0.00086085, dtype=float32),
#  array(-0.00084363, dtype=float32),
#  array(-0.00082676, dtype=float32),
#  array(-0.00081023, dtype=float32),
#  array(-0.00079402, dtype=float32),
#  array(-0.00077814, dtype=float32),
#  array(-0.00076258, dtype=float32),
#  array(-0.00074733, dtype=float32),
#  array(-0.00073238, dtype=float32),
#  array(-0.00071773, dtype=float32),
#  array(-0.00070338, dtype=float32),
#  array(-0.00068931, dtype=float32),
#  array(-0.00067552, dtype=float32),
#  array(-0.00066201, dtype=float32),
#  array(-0.00064877, dtype=float32),
#  array(-0.0006358, dtype=float32),
#  array(-0.00062308, dtype=float32),
#  array(-0.00061062, dtype=float32),
#  array(-0.00059841, dtype=float32),
#  array(-0.00058644, dtype=float32),
#  array(-0.00057471, dtype=float32),
#  array(-0.00056322, dtype=float32),
#  array(-0.00055195, dtype=float32),
#  array(-0.00054091, dtype=float32),
#  array(-0.00053009, dtype=float32),
#  array(-0.00051949, dtype=float32),
#  array(-0.0005091, dtype=float32),
#  array(-0.00049892, dtype=float32),
#  array(-0.00048894, dtype=float32),
#  array(-0.00047916, dtype=float32),
#  array(-0.00046958, dtype=float32),
#  array(-0.00046019, dtype=float32),
#  array(-0.00045099, dtype=float32),
#  array(-0.00044197, dtype=float32),
#  array(-0.00043313, dtype=float32),
#  array(-0.00042446, dtype=float32),
#  array(-0.00041597, dtype=float32),
#  array(-0.00040765, dtype=float32),
#  array(-0.0003995, dtype=float32),
#  array(-0.00039151, dtype=float32),
#  array(-0.00038368, dtype=float32),
#  array(-0.00037601, dtype=float32),
#  array(-0.00036849, dtype=float32),
#  array(-0.00036112, dtype=float32),
#  array(-0.0003539, dtype=float32),
#  array(-0.00034682, dtype=float32),
#  array(-0.00033988, dtype=float32),
#  array(-0.00033308, dtype=float32),
#  array(-0.00032642, dtype=float32),
#  array(-0.00031989, dtype=float32),
#  array(-0.0003135, dtype=float32),
#  array(-0.00030723, dtype=float32),
#  array(-0.00030108, dtype=float32),
#  array(-0.00029506, dtype=float32),
#  array(-0.00028916, dtype=float32),
#  array(-0.00028338, dtype=float32),
#  array(-0.00027771, dtype=float32),
#  array(-0.00027215, dtype=float32),
#  array(-0.00026671, dtype=float32),
#  array(-0.00026138, dtype=float32),
#  array(-0.00025615, dtype=float32),
#  array(-0.00025103, dtype=float32),
#  array(-0.00024601, dtype=float32),
#  array(-0.00024109, dtype=float32),
#  array(-0.00023626, dtype=float32),
#  array(-0.00023154, dtype=float32),
#  array(-0.00022691, dtype=float32),
#  array(-0.00022237, dtype=float32),
#  array(-0.00021792, dtype=float32),
#  array(-0.00021356, dtype=float32),
#  array(-0.00020929, dtype=float32),
#  array(-0.00020511, dtype=float32),
#  array(-0.000201, dtype=float32),
#  array(-0.00019698, dtype=float32),
#  array(-0.00019304, dtype=float32),
#  array(-0.00018918, dtype=float32),
#  array(-0.0001854, dtype=float32),
#  array(-0.00018169, dtype=float32),
#  array(-0.00017806, dtype=float32),
#  array(-0.0001745, dtype=float32),
#  array(-0.00017101, dtype=float32),
#  array(-0.00016759, dtype=float32),
#  array(-0.00016424, dtype=float32),
#  array(-0.00016095, dtype=float32),
#  array(-0.00015773, dtype=float32),
#  array(-0.00015458, dtype=float32),
#  array(-0.00015149, dtype=float32),
#  array(-0.00014846, dtype=float32),
#  array(-0.00014549, dtype=float32),
#  array(-0.00014258, dtype=float32),
#  array(-0.00013973, dtype=float32),
#  array(-0.00013693, dtype=float32),
#  array(-0.00013419, dtype=float32),
#  array(-0.00013151, dtype=float32),
#  array(-0.00012888, dtype=float32),
#  array(-0.0001263, dtype=float32),
#  array(-0.00012377, dtype=float32),
#  array(-0.0001213, dtype=float32),
#  array(-0.00011887, dtype=float32),
#  array(-0.0001165, dtype=float32),
#  array(-0.00011417, dtype=float32),
#  array(-0.00011188, dtype=float32),
#  array(-0.00010964, dtype=float32),
#  array(-0.00010745, dtype=float32),
#  array(-0.0001053, dtype=float32),
#  array(-0.0001032, dtype=float32),
#  array(-0.00010113, dtype=float32),
#  array(-9.911023e-05, dtype=float32),
#  array(-9.7128024e-05, dtype=float32),
#  array(-9.518546e-05, dtype=float32),
#  array(-9.328175e-05, dtype=float32),
#  array(-9.141612e-05, dtype=float32),
#  array(-8.9587804e-05, dtype=float32),
#  array(-8.7796056e-05, dtype=float32),
#  array(-8.6040134e-05, dtype=float32),
#  array(-8.431933e-05, dtype=float32),
#  array(-8.263295e-05, dtype=float32),
#  array(-8.098029e-05, dtype=float32),
#  array(-7.936069e-05, dtype=float32),
#  array(-7.777348e-05, dtype=float32),
#  array(-7.621801e-05, dtype=float32),
#  array(-7.469366e-05, dtype=float32),
#  array(-7.3199786e-05, dtype=float32),
#  array(-7.173579e-05, dtype=float32),
#  array(-7.0301074e-05, dtype=float32),
#  array(-6.889505e-05, dtype=float32),
#  array(-6.751715e-05, dtype=float32),
#  array(-6.61668e-05, dtype=float32),
#  array(-6.4843465e-05, dtype=float32),
#  array(-6.35466e-05, dtype=float32),
#  array(-6.227566e-05, dtype=float32),
#  array(-6.103015e-05, dtype=float32),
#  array(-5.980955e-05, dtype=float32),
#  array(-5.861336e-05, dtype=float32),
#  array(-5.7441095e-05, dtype=float32),
#  array(-5.6292272e-05, dtype=float32),
#  array(-5.5166427e-05, dtype=float32),
#  array(-5.40631e-05, dtype=float32),
#  array(-5.2981843e-05, dtype=float32),
#  array(-5.192221e-05, dtype=float32),
#  array(-5.0883762e-05, dtype=float32),
#  array(-4.986609e-05, dtype=float32),
#  array(-4.8868766e-05, dtype=float32),
#  array(-4.7891393e-05, dtype=float32),
#  array(-4.6933565e-05, dtype=float32),
#  array(-4.5994893e-05, dtype=float32),
#  array(-4.5074994e-05, dtype=float32),
#  array(-4.4173496e-05, dtype=float32),
#  array(-4.3290027e-05, dtype=float32),
#  array(-4.2424224e-05, dtype=float32),
#  array(-4.157574e-05, dtype=float32),
#  array(-4.0744228e-05, dtype=float32),
#  array(-3.9929342e-05, dtype=float32),
#  array(-3.9130755e-05, dtype=float32),
#  array(-3.834814e-05, dtype=float32),
#  array(-3.758118e-05, dtype=float32),
#  array(-3.682956e-05, dtype=float32),
#  array(-3.609297e-05, dtype=float32),
#  array(-3.5371108e-05, dtype=float32),
#  array(-3.4663688e-05, dtype=float32),
#  array(-3.3970413e-05, dtype=float32),
#  array(-3.3291006e-05, dtype=float32),
#  array(-3.2625183e-05, dtype=float32),
#  array(-3.1972682e-05, dtype=float32),
#  array(-3.1333228e-05, dtype=float32),
#  array(-3.0706564e-05, dtype=float32),
#  array(-3.0092433e-05, dtype=float32),
#  array(-2.9490584e-05, dtype=float32),
#  array(-2.8900773e-05, dtype=float32),
#  array(-2.8322756e-05, dtype=float32),
#  array(-2.7756301e-05, dtype=float32),
#  array(-2.7201175e-05, dtype=float32),
#  array(-2.6657151e-05, dtype=float32),
#  array(-2.612401e-05, dtype=float32),
#  array(-2.560153e-05, dtype=float32),
#  array(-2.50895e-05, dtype=float32),
#  array(-2.4587709e-05, dtype=float32),
#  array(-2.4095956e-05, dtype=float32),
#  array(-2.3614037e-05, dtype=float32),
#  array(-2.3141758e-05, dtype=float32),
#  array(-2.2678923e-05, dtype=float32),
#  array(-2.2225344e-05, dtype=float32),
#  array(-2.1780837e-05, dtype=float32),
#  array(-2.1345222e-05, dtype=float32),
#  array(-2.091832e-05, dtype=float32),
#  array(-2.0499952e-05, dtype=float32),
#  array(-2.0089952e-05, dtype=float32),
#  array(-1.9688152e-05, dtype=float32),
#  array(-1.9294388e-05, dtype=float32),
#  array(-1.89085e-05, dtype=float32),
#  array(-1.8530332e-05, dtype=float32),
#  array(-1.8159728e-05, dtype=float32),
#  array(-1.7796534e-05, dtype=float32),
#  array(-1.7440605e-05, dtype=float32),
#  array(-1.7091792e-05, dtype=float32),
#  array(-1.6749957e-05, dtype=float32),
#  array(-1.6414957e-05, dtype=float32),
#  array(-1.6086658e-05, dtype=float32),
#  array(-1.5764927e-05, dtype=float32),
#  array(-1.5449627e-05, dtype=float32),
#  array(-1.5140635e-05, dtype=float32),
#  array(-1.4837822e-05, dtype=float32),
#  array(-1.4541067e-05, dtype=float32),
#  array(-1.4250245e-05, dtype=float32),
#  array(-1.396524e-05, dtype=float32),
#  array(-1.3685936e-05, dtype=float32),
#  array(-1.3412218e-05, dtype=float32),
#  array(-1.3143974e-05, dtype=float32),
#  array(-1.2881095e-05, dtype=float32),
#  array(-1.2623474e-05, dtype=float32),
#  array(-1.2371005e-05, dtype=float32),
#  array(-1.2123584e-05, dtype=float32),
#  array(-1.1881113e-05, dtype=float32),
#  array(-1.1643491e-05, dtype=float32),
#  array(-1.1410622e-05, dtype=float32),
#  array(-1.118241e-05, dtype=float32),
#  array(-1.0958762e-05, dtype=float32),
#  array(-1.0739586e-05, dtype=float32),
#  array(-1.0524795e-05, dtype=float32),
#  array(-1.0314299e-05, dtype=float32),
#  array(-1.0108013e-05, dtype=float32),
#  array(-9.9058525e-06, dtype=float32),
#  array(-9.707735e-06, dtype=float32),
#  array(-9.51358e-06, dtype=float32),
#  array(-9.323308e-06, dtype=float32),
#  array(-9.136842e-06, dtype=float32),
#  array(-8.9541045e-06, dtype=float32),
#  array(-8.775023e-06, dtype=float32),
#  array(-8.599523e-06, dtype=float32),
#  array(-8.4275325e-06, dtype=float32),
#  array(-8.258981e-06, dtype=float32),
#  array(-8.0938025e-06, dtype=float32),
#  array(-7.931927e-06, dtype=float32),
#  array(-7.773289e-06, dtype=float32),
#  array(-7.617824e-06, dtype=float32),
#  array(-7.465467e-06, dtype=float32),
#  array(-7.316158e-06, dtype=float32),
#  array(-7.169835e-06, dtype=float32),
#  array(-7.0264387e-06, dtype=float32),
#  array(-6.88591e-06, dtype=float32),
#  array(-6.7481915e-06, dtype=float32),
#  array(-6.613228e-06, dtype=float32),
#  array(-6.4809637e-06, dtype=float32),
#  array(-6.3513444e-06, dtype=float32),
#  array(-6.224318e-06, dtype=float32),
#  array(-6.099832e-06, dtype=float32),
#  array(-5.977835e-06, dtype=float32),
#  array(-5.858278e-06, dtype=float32),
#  array(-5.7411125e-06, dtype=float32),
#  array(-5.6262907e-06, dtype=float32),
#  array(-5.5137652e-06, dtype=float32),
#  array(-5.40349e-06, dtype=float32),
#  array(-5.29542e-06, dtype=float32),
#  array(-5.189512e-06, dtype=float32),
#  array(-5.0857225e-06, dtype=float32),
#  array(-4.9840082e-06, dtype=float32),
#  array(-4.8843285e-06, dtype=float32),
#  array(-4.7866424e-06, dtype=float32),
#  array(-4.69091e-06, dtype=float32),
#  array(-4.597092e-06, dtype=float32),
#  array(-4.50515e-06, dtype=float32),
#  array(-4.4150474e-06, dtype=float32),
#  array(-4.3267464e-06, dtype=float32),
#  array(-4.2402116e-06, dtype=float32),
#  array(-4.1554076e-06, dtype=float32),
#  array(-4.0723e-06, dtype=float32),
#  array(-3.9908537e-06, dtype=float32),
#  array(-3.9110364e-06, dtype=float32),
#  array(-3.8328153e-06, dtype=float32),
#  array(-3.756159e-06, dtype=float32),
#  array(-3.681036e-06, dtype=float32),
#  array(-3.6074152e-06, dtype=float32),
#  array(-3.5352668e-06, dtype=float32),
#  array(-3.4645614e-06, dtype=float32),
#  array(-3.3952701e-06, dtype=float32),
#  array(-3.327365e-06, dtype=float32),
#  array(-3.2608177e-06, dtype=float32),
#  array(-3.1956015e-06, dtype=float32),
#  array(-3.1316895e-06, dtype=float32),
#  array(-3.0690558e-06, dtype=float32),
#  array(-3.0076749e-06, dtype=float32),
#  array(-2.9475214e-06, dtype=float32),
#  array(-2.888571e-06, dtype=float32),
#  array(-2.8307995e-06, dtype=float32),
#  array(-2.7741835e-06, dtype=float32),
#  array(-2.7186998e-06, dtype=float32),
#  array(-2.6643256e-06, dtype=float32),
#  array(-2.6110392e-06, dtype=float32),
#  array(-2.5588183e-06, dtype=float32),
#  array(-2.507642e-06, dtype=float32),
#  array(-2.4574892e-06, dtype=float32),
#  array(-2.4083397e-06, dtype=float32),
#  array(-2.3601729e-06, dtype=float32),
#  array(-2.3129696e-06, dtype=float32),
#  array(-2.2667105e-06, dtype=float32),
#  array(-2.2213762e-06, dtype=float32),
#  array(-2.1769488e-06, dtype=float32),
#  array(-2.13341e-06, dtype=float32),
#  array(-2.0907419e-06, dtype=float32),
#  array(-2.048927e-06, dtype=float32),
#  array(-2.0079483e-06, dtype=float32),
#  array(-1.9677896e-06, dtype=float32),
#  array(-1.928434e-06, dtype=float32),
#  array(-1.8898654e-06, dtype=float32),
#  array(-1.8520682e-06, dtype=float32),
#  array(-1.815027e-06, dtype=float32),
#  array(-1.7787265e-06, dtype=float32),
#  array(-1.7431521e-06, dtype=float32),
#  array(-1.7082891e-06, dtype=float32),
#  array(-1.6741233e-06, dtype=float32),
#  array(-1.6406409e-06, dtype=float32),
#  array(-1.6078282e-06, dtype=float32),
#  array(-1.5756716e-06, dtype=float32),
#  array(-1.5441583e-06, dtype=float32),
#  array(-1.5132753e-06, dtype=float32),
#  array(-1.4830098e-06, dtype=float32),
#  array(-1.4533496e-06, dtype=float32),
#  array(-1.4242826e-06, dtype=float32),
#  array(-1.395797e-06, dtype=float32),
#  array(-1.3678812e-06, dtype=float32),
#  array(-1.3405236e-06, dtype=float32),
#  array(-1.313713e-06, dtype=float32),
#  array(-1.2874389e-06, dtype=float32),
#  array(-1.2616902e-06, dtype=float32),
#  array(-1.2364565e-06, dtype=float32),
#  array(-1.2117273e-06, dtype=float32),
#  array(-1.1874927e-06, dtype=float32),
#  array(-1.1637428e-06, dtype=float32),
#  array(-1.1404679e-06, dtype=float32),
#  array(-1.1176585e-06, dtype=float32),
#  array(-1.0953054e-06, dtype=float32),
#  array(-1.0733993e-06, dtype=float32),
#  array(-1.0519313e-06, dtype=float32),
#  array(-1.0308927e-06, dtype=float32),
#  array(-1.0102749e-06, dtype=float32),
#  array(-9.900693e-07, dtype=float32),
#  array(-9.70268e-07, dtype=float32),
#  array(-9.508626e-07, dtype=float32),
#  array(-9.318454e-07, dtype=float32),
#  array(-9.132085e-07, dtype=float32),
#  array(-8.949444e-07, dtype=float32),
#  array(-8.770455e-07, dtype=float32),
#  array(-8.5950467e-07, dtype=float32),
#  array(-8.4231453e-07, dtype=float32),
#  array(-8.254683e-07, dtype=float32),
#  array(-8.0895893e-07, dtype=float32),
#  array(-7.927798e-07, dtype=float32),
#  array(-7.7692425e-07, dtype=float32),
#  array(-7.6138576e-07, dtype=float32),
#  array(-7.461581e-07, dtype=float32),
#  array(-7.31235e-07, dtype=float32),
#  array(-7.166103e-07, dtype=float32),
#  array(-7.0227816e-07, dtype=float32),
#  array(-6.882326e-07, dtype=float32),
#  array(-6.7446797e-07, dtype=float32),
#  array(-6.6097857e-07, dtype=float32),
#  array(-6.4775907e-07, dtype=float32),
#  array(-6.348039e-07, dtype=float32),
#  array(-6.221078e-07, dtype=float32),
#  array(-6.096657e-07, dtype=float32),
#  array(-5.974724e-07, dtype=float32),
#  array(-5.85523e-07, dtype=float32),
#  array(-5.738126e-07, dtype=float32),
#  array(-5.6233637e-07, dtype=float32),
#  array(-5.5108967e-07, dtype=float32),
#  array(-5.4006784e-07, dtype=float32),
#  array(-5.2926646e-07, dtype=float32),
#  array(-5.186812e-07, dtype=float32),
#  array(-5.083076e-07, dtype=float32),
#  array(-4.981415e-07, dtype=float32),
#  array(-4.8817867e-07, dtype=float32),
#  array(-4.7841513e-07, dtype=float32),
#  array(-4.6884685e-07, dtype=float32),
#  array(-4.594699e-07, dtype=float32),
#  array(-4.5028054e-07, dtype=float32),
#  array(-4.4127495e-07, dtype=float32),
#  array(-4.3244944e-07, dtype=float32),
#  array(-4.238005e-07, dtype=float32),
#  array(-4.153245e-07, dtype=float32),
#  array(-4.0701804e-07, dtype=float32),
#  array(-3.9887766e-07, dtype=float32),
#  array(-3.9090014e-07, dtype=float32),
#  array(-3.8308212e-07, dtype=float32),
#  array(-3.7542048e-07, dtype=float32),
#  array(-3.679121e-07, dtype=float32),
#  array(-3.6055388e-07, dtype=float32),
#  array(-3.5334284e-07, dtype=float32),
#  array(-3.46276e-07, dtype=float32),
#  array(-3.393505e-07, dtype=float32),
#  array(-3.325635e-07, dtype=float32),
#  array(-3.2591225e-07, dtype=float32),
#  array(-3.1939402e-07, dtype=float32),
#  array(-3.1300613e-07, dtype=float32),
#  array(-3.0674602e-07, dtype=float32),
#  array(-3.0061108e-07, dtype=float32),
#  array(-2.9459886e-07, dtype=float32),
#  array(-2.8870687e-07, dtype=float32),
#  array(-2.8293272e-07, dtype=float32),
#  array(-2.7727407e-07, dtype=float32),
#  array(-2.717286e-07, dtype=float32),
#  array(-2.6629402e-07, dtype=float32),
#  array(-2.6096814e-07, dtype=float32),
#  array(-2.5574877e-07, dtype=float32),
#  array(-2.5063378e-07, dtype=float32),
#  array(-2.456211e-07, dtype=float32),
#  array(-2.407087e-07, dtype=float32),
#  array(-2.358945e-07, dtype=float32),
#  array(-2.3117661e-07, dtype=float32),
#  array(-2.2655308e-07, dtype=float32),
#  array(-2.2202204e-07, dtype=float32),
#  array(-2.175816e-07, dtype=float32),
#  array(-2.1322998e-07, dtype=float32),
#  array(-2.0896539e-07, dtype=float32),
#  array(-2.0478609e-07, dtype=float32),
#  array(-2.0069038e-07, dtype=float32),
#  array(-1.9667658e-07, dtype=float32),
#  array(-1.9274304e-07, dtype=float32),
#  array(-1.8888818e-07, dtype=float32),
#  array(-1.8511042e-07, dtype=float32),
#  array(-1.8140821e-07, dtype=float32),
#  array(-1.7778004e-07, dtype=float32),
#  array(-1.7422445e-07, dtype=float32),
#  array(-1.7073998e-07, dtype=float32),
#  array(-1.673252e-07, dtype=float32),
#  array(-1.6397868e-07, dtype=float32),
#  array(-1.606991e-07, dtype=float32),
#  array(-1.5748512e-07, dtype=float32),
#  array(-1.5433542e-07, dtype=float32),
#  array(-1.5124871e-07, dtype=float32),
#  array(-1.4822373e-07, dtype=float32),
#  array(-1.4525926e-07, dtype=float32),
#  array(-1.4235408e-07, dtype=float32),
#  array(-1.39507e-07, dtype=float32),
#  array(-1.3671686e-07, dtype=float32),
#  array(-1.3398252e-07, dtype=float32),
#  array(-1.3130287e-07, dtype=float32),
#  array(-1.2867682e-07, dtype=float32),
#  array(-1.2610329e-07, dtype=float32),
#  array(-1.2358123e-07, dtype=float32),
#  array(-1.2110962e-07, dtype=float32),
#  array(-1.1868744e-07, dtype=float32),
#  array(-1.16313686e-07, dtype=float32),
#  array(-1.1398741e-07, dtype=float32),
#  array(-1.11707664e-07, dtype=float32),
#  array(-1.0947352e-07, dtype=float32),
#  array(-1.0728405e-07, dtype=float32),
#  array(-1.0513837e-07, dtype=float32),
#  array(-1.030356e-07, dtype=float32),
#  array(-1.0097489e-07, dtype=float32),
#  array(-9.89554e-08, dtype=float32),
#  array(-9.6976294e-08, dtype=float32),
#  array(-9.503677e-08, dtype=float32),
#  array(-9.313604e-08, dtype=float32),
#  array(-9.127332e-08, dtype=float32),
#  array(-8.944785e-08, dtype=float32),
#  array(-8.765889e-08, dtype=float32),
#  array(-8.590571e-08, dtype=float32),
#  array(-8.4187604e-08, dtype=float32),
#  array(-8.250386e-08, dtype=float32),
#  array(-8.085378e-08, dtype=float32),
#  array(-7.923671e-08, dtype=float32),
#  array(-7.7651976e-08, dtype=float32),
#  array(-7.609894e-08, dtype=float32),
#  array(-7.457696e-08, dtype=float32),
#  array(-7.308542e-08, dtype=float32),
#  array(-7.162372e-08, dtype=float32),
#  array(-7.019125e-08, dtype=float32),
#  array(-6.878743e-08, dtype=float32),
#  array(-6.7411676e-08, dtype=float32),
#  array(-6.606345e-08, dtype=float32),
#  array(-6.474218e-08, dtype=float32),
#  array(-6.3447345e-08, dtype=float32),
#  array(-6.21784e-08, dtype=float32),
#  array(-6.093484e-08, dtype=float32),
#  array(-5.971614e-08, dtype=float32),
#  array(-5.852182e-08, dtype=float32),
#  array(-5.7351386e-08, dtype=float32),
#  array(-5.6204357e-08, dtype=float32),
#  array(-5.508027e-08, dtype=float32),
#  array(-5.3978667e-08, dtype=float32),
#  array(-5.2899097e-08, dtype=float32),
#  array(-5.1841113e-08, dtype=float32),
#  array(-5.080429e-08, dtype=float32),
#  array(-4.9788206e-08, dtype=float32),
#  array(-4.8792444e-08, dtype=float32),
#  array(-4.78166e-08, dtype=float32),
#  array(-4.6860265e-08, dtype=float32),
#  array(-4.592306e-08, dtype=float32),
#  array(-4.5004597e-08, dtype=float32),
#  array(-4.4104503e-08, dtype=float32),
#  array(-4.3222414e-08, dtype=float32),
#  array(-4.2357968e-08, dtype=float32),
#  array(-4.151081e-08, dtype=float32),
#  array(-4.0680597e-08, dtype=float32),
#  array(-3.9866983e-08, dtype=float32),
#  array(-3.9069647e-08, dtype=float32),
#  array(-3.8288256e-08, dtype=float32),
#  array(-3.752249e-08, dtype=float32),
#  array(-3.6772043e-08, dtype=float32),
#  array(-3.6036603e-08, dtype=float32),
#  array(-3.531587e-08, dtype=float32),
#  array(-3.4609556e-08, dtype=float32),
#  array(-3.3917367e-08, dtype=float32),
#  array(-3.323902e-08, dtype=float32),
#  array(-3.2574242e-08, dtype=float32),
#  array(-3.192276e-08, dtype=float32),
#  array(-3.128431e-08, dtype=float32),
#  array(-3.0658626e-08, dtype=float32),
#  array(-3.0045456e-08, dtype=float32),
#  array(-2.9444546e-08, dtype=float32),
#  array(-2.8855656e-08, dtype=float32),
#  array(-2.8278542e-08, dtype=float32),
#  array(-2.7712971e-08, dtype=float32),
#  array(-2.7158713e-08, dtype=float32),
#  array(-2.6615538e-08, dtype=float32),
#  array(-2.6083228e-08, dtype=float32),
#  array(-2.5561565e-08, dtype=float32),
#  array(-2.5050333e-08, dtype=float32),
#  array(-2.4549326e-08, dtype=float32),
#  array(-2.4058341e-08, dtype=float32),
#  array(-2.3577176e-08, dtype=float32),
#  array(-2.3105631e-08, dtype=float32),
#  array(-2.2643519e-08, dtype=float32),
#  array(-2.2190648e-08, dtype=float32),
#  array(-2.1746835e-08, dtype=float32),
#  array(-2.1311898e-08, dtype=float32),
#  array(-2.0885661e-08, dtype=float32),
#  array(-2.0467947e-08, dtype=float32),
#  array(-2.005859e-08, dtype=float32),
#  array(-1.9657417e-08, dtype=float32),
#  array(-1.926427e-08, dtype=float32),
#  array(-1.8878985e-08, dtype=float32),
#  array(-1.8501407e-08, dtype=float32),
#  array(-1.8131377e-08, dtype=float32),
#  array(-1.7768752e-08, dtype=float32),
#  array(-1.7413377e-08, dtype=float32),
#  array(-1.7065108e-08, dtype=float32),
#  array(-1.6723806e-08, dtype=float32),
#  array(-1.6389329e-08, dtype=float32),
#  array(-1.6061541e-08, dtype=float32),
#  array(-1.5740312e-08, dtype=float32),
#  array(-1.5425506e-08, dtype=float32),
#  array(-1.5116996e-08, dtype=float32),
#  array(-1.4814656e-08, dtype=float32),
#  array(-1.4518363e-08, dtype=float32),
#  array(-1.4227997e-08, dtype=float32),
#  array(-1.3943437e-08, dtype=float32),
#  array(-1.3664568e-08, dtype=float32),
#  array(-1.3391277e-08, dtype=float32),
#  array(-1.31234525e-08, dtype=float32),
#  array(-1.2860983e-08, dtype=float32),
#  array(-1.2603763e-08, dtype=float32),
#  array(-1.2351688e-08, dtype=float32),
#  array(-1.2104653e-08, dtype=float32),
#  array(-1.1862561e-08, dtype=float32),
#  array(-1.16253105e-08, dtype=float32),
#  array(-1.1392805e-08, dtype=float32),
#  array(-1.116495e-08, dtype=float32),
#  array(-1.0941651e-08, dtype=float32),
#  array(-1.0722818e-08, dtype=float32),
#  array(-1.0508362e-08, dtype=float32),
#  array(-1.0298194e-08, dtype=float32),
#  array(-1.0092231e-08, dtype=float32),
#  array(-9.890387e-09, dtype=float32),
#  array(-9.692579e-09, dtype=float32),
#  array(-9.498727e-09, dtype=float32),
#  array(-9.308753e-09, dtype=float32),
#  array(-9.122578e-09, dtype=float32),
#  array(-8.940127e-09, dtype=float32),
#  array(-8.761324e-09, dtype=float32),
#  array(-8.586097e-09, dtype=float32),
#  array(-8.414375e-09, dtype=float32),
#  array(-8.246088e-09, dtype=float32),
#  array(-8.081166e-09, dtype=float32),
#  array(-7.919542e-09, dtype=float32),
#  array(-7.761152e-09, dtype=float32),
#  array(-7.605928e-09, dtype=float32),
#  array(-7.45381e-09, dtype=float32),
#  array(-7.3047337e-09, dtype=float32),
#  array(-7.158639e-09, dtype=float32),
#  array(-7.0154664e-09, dtype=float32),
#  array(-6.8751573e-09, dtype=float32),
#  array(-6.737654e-09, dtype=float32),
#  array(-6.6029013e-09, dtype=float32),
#  array(-6.4708434e-09, dtype=float32),
#  array(-6.341427e-09, dtype=float32),
#  array(-6.2145986e-09, dtype=float32),
#  array(-6.090307e-09, dtype=float32),
#  array(-5.9685012e-09, dtype=float32),
#  array(-5.849131e-09, dtype=float32),
#  array(-5.732148e-09, dtype=float32),
#  array(-5.6175056e-09, dtype=float32),
#  array(-5.5051554e-09, dtype=float32),
#  array(-5.3950524e-09, dtype=float32),
#  array(-5.287151e-09, dtype=float32),
#  array(-5.181408e-09, dtype=float32),
#  array(-5.07778e-09, dtype=float32),
#  array(-4.9762248e-09, dtype=float32),
#  array(-4.8767e-09, dtype=float32),
#  array(-4.7791664e-09, dtype=float32),
#  array(-4.6835833e-09, dtype=float32),
#  array(-4.5899116e-09, dtype=float32),
#  array(-4.498113e-09, dtype=float32),
#  array(-4.408151e-09, dtype=float32),
#  array(-4.319988e-09, dtype=float32),
#  array(-4.2335886e-09, dtype=float32),
#  array(-4.1489168e-09, dtype=float32),
#  array(-4.0659387e-09, dtype=float32),
#  array(-3.9846197e-09, dtype=float32),
#  array(-3.904927e-09, dtype=float32),
#  array(-3.8268286e-09, dtype=float32),
#  array(-3.7502925e-09, dtype=float32),
#  array(-3.6752867e-09, dtype=float32),
#  array(-3.601781e-09, dtype=float32),
#  array(-3.5297454e-09, dtype=float32),
#  array(-3.4591507e-09, dtype=float32),
#  array(-3.3899679e-09, dtype=float32),
#  array(-3.3221688e-09, dtype=float32),
#  array(-3.2557255e-09, dtype=float32),
#  array(-3.1906109e-09, dtype=float32),
#  array(-3.1267988e-09, dtype=float32),
#  array(-3.064263e-09, dtype=float32),
#  array(-3.0029779e-09, dtype=float32),
#  array(-2.9429184e-09, dtype=float32),
#  array(-2.88406e-09, dtype=float32),
#  array(-2.8263791e-09, dtype=float32),
#  array(-2.7698515e-09, dtype=float32),
#  array(-2.7144544e-09, dtype=float32),
#  array(-2.6601654e-09, dtype=float32),
#  array(-2.6069622e-09, dtype=float32),
#  array(-2.554823e-09, dtype=float32),
#  array(-2.5037266e-09, dtype=float32),
#  array(-2.453652e-09, dtype=float32),
#  array(-2.4045788e-09, dtype=float32),
#  array(-2.3564874e-09, dtype=float32),
#  array(-2.3093576e-09, dtype=float32),
#  array(-2.2631705e-09, dtype=float32),
#  array(-2.2179072e-09, dtype=float32),
#  array(-2.173549e-09, dtype=float32),
#  array(-2.130078e-09, dtype=float32),
#  array(-2.0874764e-09, dtype=float32),
#  array(-2.0457271e-09, dtype=float32),
#  array(-2.0048128e-09, dtype=float32),
#  array(-1.9647164e-09, dtype=float32),
#  array(-1.925422e-09, dtype=float32),
#  array(-1.8869137e-09, dtype=float32),
#  array(-1.8491755e-09, dtype=float32),
#  array(-1.812192e-09, dtype=float32),
#  array(-1.775948e-09, dtype=float32),
#  array(-1.7404291e-09, dtype=float32),
#  array(-1.7056205e-09, dtype=float32),
#  array(-1.6715083e-09, dtype=float32),
#  array(-1.6380781e-09, dtype=float32),
#  array(-1.6053165e-09, dtype=float32),
#  array(-1.5732102e-09, dtype=float32),
#  array(-1.5417461e-09, dtype=float32),
#  array(-1.5109112e-09, dtype=float32),
#  array(-1.4806929e-09, dtype=float32),
#  array(-1.451079e-09, dtype=float32),
#  array(-1.4220576e-09, dtype=float32),
#  array(-1.3936166e-09, dtype=float32),
#  array(-1.3657442e-09, dtype=float32),
#  array(-1.3384294e-09, dtype=float32),
#  array(-1.3116608e-09, dtype=float32),
#  array(-1.2854275e-09, dtype=float32),
#  array(-1.259719e-09, dtype=float32),
#  array(-1.2345247e-09, dtype=float32),
#  array(-1.2098342e-09, dtype=float32),
#  array(-1.1856376e-09, dtype=float32),
#  array(-1.1619248e-09, dtype=float32),
#  array(-1.1386863e-09, dtype=float32),
#  array(-1.1159125e-09, dtype=float32),
#  array(-1.0935943e-09, dtype=float32),
#  array(-1.0717225e-09, dtype=float32),
#  array(-1.0502881e-09, dtype=float32),
#  array(-1.0292824e-09, dtype=float32),
#  array(-1.0086969e-09, dtype=float32),
#  array(-9.88523e-10, dtype=float32),
#  array(-9.687526e-10, dtype=float32),
#  array(-9.493777e-10, dtype=float32),
#  array(-9.303902e-10, dtype=float32),
#  array(-9.117824e-10, dtype=float32),
#  array(-8.935468e-10, dtype=float32),
#  array(-8.7567587e-10, dtype=float32),
#  array(-8.581623e-10, dtype=float32),
#  array(-8.4099905e-10, dtype=float32),
#  array(-8.2417906e-10, dtype=float32),
#  array(-8.0769547e-10, dtype=float32),
#  array(-7.915416e-10, dtype=float32),
#  array(-7.7571083e-10, dtype=float32),
#  array(-7.601966e-10, dtype=float32),
#  array(-7.449926e-10, dtype=float32),
#  array(-7.3009276e-10, dtype=float32),
#  array(-7.154909e-10, dtype=float32),
#  array(-7.011811e-10, dtype=float32),
#  array(-6.8715755e-10, dtype=float32),
#  array(-6.7341444e-10, dtype=float32),
#  array(-6.599462e-10, dtype=float32),
#  array(-6.467473e-10, dtype=float32),
#  ...]

# %%
matplotlib.rcParams['figure.figsize'] = [10, 10]

labels = [f"$w_{i+1}$" for i in range(1)]

plt.gca().set_prop_cycle(None)
solid_lines = plt.plot(history, linestyle='-', label=labels)

solid_legend = plt.legend(handles=solid_lines, title='solid action', loc=[0.03, 0.7])
plt.gca().add_artist(solid_legend)

plt.grid(True)
plt.xlabel("Steps")

plt.show()
